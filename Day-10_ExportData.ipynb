# %%
import pandas as pd

df = pd.read_csv('filtered_dataset.csv')  # tumhara already cleaned/filtered data

df.to_csv('final_cleaned_dataset.csv', index=False)

# %%
check = pd.read_csv('final_cleaned_dataset.csv')
check.head()
# Out:
#    OrderID CustomerName       City   Product     Category  Quantity     Price  \
# 0        2        Anita     Mumbai    Webcam  Accessories         4   2073.24
# 1        4        Anita  Hyderabad  Keyboard  Accessories         4  29668.65
# 2        6        Arjun     Mumbai    Mobile  Electronics         4   5287.46
# 3        7      Shalini    Kolkata    Laptop  Electronics         4  27043.29
# 4       12       Suresh  Hyderabad     Mouse  Accessories         5  11370.95
#
#     OrderDate
# 0  2026-01-07
# 1  2026-07-28
# 2  2026-07-12
# 3  2026-04-03
# 4  2026-03-27
